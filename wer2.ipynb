# %% [markdown]
# <a href="https://colab.research.google.com/github/Vyankteshv/new/blob/main/wer2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m venv <New>
# !source <New>/bin/activate
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `python -m venv <New>'
# /bin/bash: line 1: New: No such file or directory

# %%
# !sudo apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !pip install jiwer

import jiwer

# Example reference transcripts
reference_transcripts = [
    "this is a reference transcript",
    "another reference transcript"
]

# Example hypothesis transcripts (transcripts generated by your system)
hypothesis_transcripts = [
    "this is a hypothesis transcript",
    "yet another hypothesis transcript"
]

# Calculate WER
wer = jiwer.wer(reference_transcripts, hypothesis_transcripts)
print("Word Error Rate:", wer)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 12.1 MB/s eta 0:00:00
# ...
# Word Error Rate: 0.375
